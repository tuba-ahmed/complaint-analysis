# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize, FreqDist
from nltk.stem.wordnet import WordNetLemmatizer
import string
import plotly
import plotly.graph_objects as go
import plotly.express as px
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
#Reading the dataset. 
df = pd.read_csv('complaints.csv')
# Out:
# /var/folders/3n/y6l_g9s960lc_759jvhdhxp40000gn/T/ipykernel_15696/2659859474.py:2: DtypeWarning: Columns (9,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('complaints.csv')

# %%
#Data frame before performing data cleanup.
df
# Out:
#         Date received                                            Product  \
# 0          2022-11-22  Credit reporting, credit repair services, or o...
# 1          2022-11-16  Credit reporting, credit repair services, or o...
# 2          2022-11-09                                    Debt collection
# 3          2022-11-07                                           Mortgage
# 4          2022-11-07                                    Debt collection
# ...               ...                                                ...
# 3096751    2017-02-09                                    Debt collection
# 3096752    2015-04-29                                           Mortgage
# 3096753    2017-03-31                                   Credit reporting
# 3096754    2017-01-16                                   Credit reporting
# 3096755    2018-03-07                                           Mortgage
#
#                          Sub-product  \
# 0                   Credit reporting
# 1                   Credit reporting
# 2                   Credit card debt
# 3             Other type of mortgage
# 4                         Other debt
# ...                              ...
# 3096751                I do not know
# 3096752  Conventional fixed mortgage
# 3096753                          NaN
# 3096754                          NaN
# 3096755       Other type of mortgage
#
#                                                      Issue  \
# 0                              Improper use of your report
# 1        Problem with a credit reporting company's inve...
# 2        Took or threatened to take negative or legal a...
# 3                           Trouble during payment process
# 4                        Attempts to collect debt not owed
# ...                                                    ...
# 3096751              Cont'd attempts collect debt not owed
# 3096752           Loan modification,collection,foreclosure
# 3096753           Credit reporting company's investigation
# 3096754             Incorrect information on credit report
# 3096755                     Trouble during payment process
#
#                                                  Sub-issue  \
# 0            Reporting company used your report improperly
# 1        Their investigation did not fix an error on yo...
# 2        Threatened or suggested your credit would be d...
# 3                                                      NaN
# 4                                        Debt is not yours
# ...                                                    ...
# 3096751                  Debt resulted from identity theft
# 3096752                                                NaN
# 3096753           No notice of investigation status/result
# 3096754                                     Account status
# 3096755                                                NaN
#
#                               Consumer complaint narrative  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 3096751  I have disputed my debts several times with no...
# 3096752  My father died in XX/XX/XXXX. Left me his only...
# 3096753  cfbp i would Like to file a complaint on Exper...
# 3096754  My husband and I are in the middle of an FHA S...
# 3096755                                                NaN
#
#                                    Company public response  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 3096751                                                NaN
# 3096752                                                NaN
# 3096753  Company has responded to the consumer and the ...
# 3096754  Company has responded to the consumer and the ...
# 3096755  Company has responded to the consumer and the ...
#
#                                         Company State ZIP code           Tags  \
# 0                                 EQUIFAX, INC.    OK  74447.0  Servicemember
# 1           Experian Information Solutions Inc.    NJ   7093.0            NaN
# 2                Genesis FS Card Services, Inc.    TX  75038.0            NaN
# 3              NORTHERN OHIO INVESTMENT COMPANY    MO  63031.0            NaN
# 4                R & R Collection Service, Inc.    MO  64154.0            NaN
# ...                                         ...   ...      ...            ...
# 3096751      Bonneville Billing and Collections    UT  84054.0  Servicemember
# 3096752                          CITIBANK, N.A.    OK  74066.0            NaN
# 3096753     Experian Information Solutions Inc.    MN  55379.0            NaN
# 3096754  TRANSUNION INTERMEDIATE HOLDINGS, INC.    GA  30215.0            NaN
# 3096755                   WELLS FARGO & COMPANY    CA  91304.0            NaN
#
#         Consumer consent provided? Submitted via Date sent to company  \
# 0                              NaN           Web           2022-11-22
# 1                              NaN           Web           2022-11-16
# 2                              NaN           Web           2022-11-09
# 3                            Other           Web           2022-11-08
# 4                              NaN         Phone           2022-11-07
# ...                            ...           ...                  ...
# 3096751           Consent provided           Web           2017-02-09
# 3096752           Consent provided           Web           2015-04-29
# 3096753           Consent provided           Web           2017-03-31
# 3096754           Consent provided           Web           2017-01-16
# 3096755                        NaN      Referral           2018-03-08
#
#             Company response to consumer Timely response? Consumer disputed?  \
# 0                            In progress              Yes                NaN
# 1                            In progress              Yes                NaN
# 2                Closed with explanation              Yes                NaN
# 3                      Untimely response               No                NaN
# 4                      Untimely response               No                NaN
# ...                                  ...              ...                ...
# 3096751          Closed with explanation              Yes                 No
# 3096752          Closed with explanation              Yes                 No
# 3096753  Closed with non-monetary relief              Yes                Yes
# 3096754          Closed with explanation              Yes                 No
# 3096755          Closed with explanation              Yes                NaN
#
#          Complaint ID
# 0             6231498
# 1             6205383
# 2             6182699
# 3             6173945
# 4             6175998
# ...               ...
# 3096751       2334969
# 3096752       1352738
# 3096753       2412926
# 3096754       2292586
# 3096755       2837068
#
# [3096756 rows x 18 columns]

# %% [markdown]
# ##### Since we are only focused on the products and complaint narratives, we will re-create the data frame using only the 'Product' and 'Consumer complaint narrative' attributes.

# %%
df = df[['Product' , 'Consumer complaint narrative']]

# %%
#Rename attributes of dataframe for simplicity.
df = df.rename(columns={'Product' : "Product",
                       'Consumer complaint narrative' : "Complaint"})

# %%
#Data frame after renaming attributes.
df
# Out:
#                                                    Product  \
# 0        Credit reporting, credit repair services, or o...
# 1        Credit reporting, credit repair services, or o...
# 2                                          Debt collection
# 3                                                 Mortgage
# 4                                          Debt collection
# ...                                                    ...
# 3096751                                    Debt collection
# 3096752                                           Mortgage
# 3096753                                   Credit reporting
# 3096754                                   Credit reporting
# 3096755                                           Mortgage
#
#                                                  Complaint
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 3096751  I have disputed my debts several times with no...
# 3096752  My father died in XX/XX/XXXX. Left me his only...
# 3096753  cfbp i would Like to file a complaint on Exper...
# 3096754  My husband and I are in the middle of an FHA S...
# 3096755                                                NaN
#
# [3096756 rows x 2 columns]

# %%
df.groupby('Product').count()
# Out:
#                                                     Complaint
# Product
# Bank account or service                                 14885
# Checking or savings account                             54190
# Consumer Loan                                            9470
# Credit card                                             18838
# Credit card or prepaid card                             81787
# Credit reporting                                        31588
# Credit reporting, credit repair services, or ot...     514280
# Debt collection                                        191946
# Money transfer, virtual currency, or money service      26556
# Money transfers                                          1497
# Mortgage                                                97748
# Other financial service                                   292
# Payday loan                                              1746
# Payday loan, title loan, or personal loan               13563
# Prepaid card                                             1450
# Student loan                                            32695
# Vehicle loan or lease                                   19873
# Virtual currency                                           16

# %% [markdown]
# ##### Many of the products of the same category can be merged together into a single product category.

# %%
#Clean up data by renaming similar products into one category of products.
df['Product'].replace({'Bank account or service': 'Banking Services',
                       'Checking or savings account' : 'Banking Services',
                       'Consumer Loan' : 'Loans',
                       'Credit card' : 'Credit/Prepaid Cards',
                       'Credit card or prepaid card' : 'Credit/Prepaid Cards',
                       'Credit reporting' : 'Credit Reporting and Services',
                       'Credit reporting, credit repair services, or other personal consumer reports' : 'Credit Reporting and Services',
                       'Debt collection' : 'Debt Collection',
                       'Money transfer, virtual currency, or money service' : 'Banking Services',
                       'Money transfers' : 'Banking Services',
                       'Mortgage' : 'Mortgages',
                       'Other financial service' : 'Banking Services',
                       'Payday loan' : 'Loans',
                       'Payday loan, title loan, or personal loan' : 'Loans',
                       'Prepaid card' : 'Credit/Prepaid Cards',
                       'Student loan' : 'Loans',
                       'Vehicle loan or lease' : 'Loans',
                       'Virtual currency' : 'Crypto Currency'}, inplace=True)

# %%
#Refined products and their counts.
df.groupby('Product').count()
# Out:
#                                Complaint
# Product
# Banking Services                   97420
# Credit Reporting and Services     545868
# Credit/Prepaid Cards              102075
# Crypto Currency                       16
# Debt Collection                   191946
# Loans                              77347
# Mortgages                          97748

# %%
#Data frame with refined product categories.
df
# Out:
#                                Product  \
# 0        Credit Reporting and Services
# 1        Credit Reporting and Services
# 2                      Debt Collection
# 3                            Mortgages
# 4                      Debt Collection
# ...                                ...
# 3096751                Debt Collection
# 3096752                      Mortgages
# 3096753  Credit Reporting and Services
# 3096754  Credit Reporting and Services
# 3096755                      Mortgages
#
#                                                  Complaint
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 3096751  I have disputed my debts several times with no...
# 3096752  My father died in XX/XX/XXXX. Left me his only...
# 3096753  cfbp i would Like to file a complaint on Exper...
# 3096754  My husband and I are in the middle of an FHA S...
# 3096755                                                NaN
#
# [3096756 rows x 2 columns]
