# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize, FreqDist
import string

# %%
def plotCountPlot(df, column, title, xlabel, ylabel, figsize=(10, 5), invert=False):
    '''
      Function to plot count plot for a given column in a dataframe
    '''
    plt.figure(figsize=figsize)
    if invert:
        sb.countplot(y=column, data=df)
    else:
      sb.countplot(x=column, data=df)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %% [markdown]
# ##### Loading the data

# %%
# Reading the data
df = pd.read_csv('data/complaints.csv')
# Out:
# c:\Users\akaid\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (9,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Initial investiogation of the data
df.head()
# Out:
#   Date received                                            Product  \
# 0    2022-11-22  Credit reporting, credit repair services, or o...
# 1    2022-11-16  Credit reporting, credit repair services, or o...
# 2    2022-11-09                                    Debt collection
# 3    2022-11-07                                           Mortgage
# 4    2022-11-07                                    Debt collection
#
#               Sub-product                                              Issue  \
# 0        Credit reporting                        Improper use of your report
# 1        Credit reporting  Problem with a credit reporting company's inve...
# 2        Credit card debt  Took or threatened to take negative or legal a...
# 3  Other type of mortgage                     Trouble during payment process
# 4              Other debt                  Attempts to collect debt not owed
#
#                                            Sub-issue  \
# 0      Reporting company used your report improperly
# 1  Their investigation did not fix an error on yo...
# 2  Threatened or suggested your credit would be d...
# 3                                                NaN
# 4                                  Debt is not yours
#
#   Consumer complaint narrative Company public response  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
#
#                                Company State ZIP code           Tags  \
# 0                        EQUIFAX, INC.    OK    74447  Servicemember
# 1  Experian Information Solutions Inc.    NJ     7093            NaN
# 2       Genesis FS Card Services, Inc.    TX    75038            NaN
# 3     NORTHERN OHIO INVESTMENT COMPANY    MO    63031            NaN
# 4       R & R Collection Service, Inc.    MO    64154            NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0                        NaN           Web           2022-11-22
# 1                        NaN           Web           2022-11-16
# 2                        NaN           Web           2022-11-09
# 3                      Other           Web           2022-11-08
# 4                        NaN         Phone           2022-11-07
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0                  In progress              Yes                NaN
# 1                  In progress              Yes                NaN
# 2      Closed with explanation              Yes                NaN
# 3            Untimely response               No                NaN
# 4            Untimely response               No                NaN
#
#    Complaint ID
# 0       6231498
# 1       6205383
# 2       6182699
# 3       6173945
# 4       6175998

# %%
print(df.shape)
# Out:
# (3096756, 18)

# %% [markdown]
# We read the data above. Now we rename the column names for our ease.

# %%
'''Get list of all column names'''
col_list = df.columns.tolist()
# print(col_list)

''' Renaming the columns for ease of access'''
df = df.rename(columns={'Date received':'date_received', 'Product':'product', 'Sub-product':'sub_product', 'Issue':'issue', 'Sub-issue':'sub_issue', 'Consumer complaint narrative':'narrative', 'Company public response':'response_public', 'Company':'company', 'State':'state', 'ZIP code':'zip', 'Tags':'tags', 'Consumer consent provided?':'consent', 'Submitted via':'submitted_via', 'Date sent to company':'date_sent', 'Company response to consumer':'response_to_cust', 'Timely response?':'timely_resp', 'Consumer disputed?':'consumer_disputed', 'Complaint ID':'id'})
df.head()
# Out:
#   date_received                                            product  \
# 0    2022-11-22  Credit reporting, credit repair services, or o...
# 1    2022-11-16  Credit reporting, credit repair services, or o...
# 2    2022-11-09                                    Debt collection
# 3    2022-11-07                                           Mortgage
# 4    2022-11-07                                    Debt collection
#
#               sub_product                                              issue  \
# 0        Credit reporting                        Improper use of your report
# 1        Credit reporting  Problem with a credit reporting company's inve...
# 2        Credit card debt  Took or threatened to take negative or legal a...
# 3  Other type of mortgage                     Trouble during payment process
# 4              Other debt                  Attempts to collect debt not owed
#
#                                            sub_issue narrative  \
# 0      Reporting company used your report improperly       NaN
# 1  Their investigation did not fix an error on yo...       NaN
# 2  Threatened or suggested your credit would be d...       NaN
# 3                                                NaN       NaN
# 4                                  Debt is not yours       NaN
#
#   response_public                              company state    zip  \
# 0             NaN                        EQUIFAX, INC.    OK  74447
# 1             NaN  Experian Information Solutions Inc.    NJ   7093
# 2             NaN       Genesis FS Card Services, Inc.    TX  75038
# 3             NaN     NORTHERN OHIO INVESTMENT COMPANY    MO  63031
# 4             NaN       R & R Collection Service, Inc.    MO  64154
#
#             tags consent submitted_via   date_sent         response_to_cust  \
# 0  Servicemember     NaN           Web  2022-11-22              In progress
# 1            NaN     NaN           Web  2022-11-16              In progress
# 2            NaN     NaN           Web  2022-11-09  Closed with explanation
# 3            NaN   Other           Web  2022-11-08        Untimely response
# 4            NaN     NaN         Phone  2022-11-07        Untimely response
#
#   timely_resp consumer_disputed       id
# 0         Yes               NaN  6231498
# 1         Yes               NaN  6205383
# 2         Yes               NaN  6182699
# 3          No               NaN  6173945
# 4          No               NaN  6175998

# %% [markdown]
# Since the goal of this notebook is to see if we can perform product classification, we will now plot the product and sub-product columns to seee if that tells us something.

# %%
# Plotting the countplot for 'product' column
sb.countplot(data=df, y='product')
# Out:
# <AxesSubplot:xlabel='count', ylabel='product'>

# %%
# Plotting the countplot for 'sub_product' column
sb_plot = sb.countplot(data=df, y='sub_product')
plt.figure(figsize=(4,8))
sb_plot.set_xticklabels(sb_plot.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-9-4c7f7a025704>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   sb_plot.set_xticklabels(sb_plot.get_xticklabels(), rotation=40, ha="right")

# %% [markdown]
# From the above plots, we can see the data is **highly imbalanced**.
#
# * From the first graph, most of the data belongs to the "Credit reporting, credit repair services, or other personal consumer reports".
# * From the second graph, most of the data belongs to the "Credit reporting" class.
#
# The second graph only tells us that the data is imbalance. But there are too many sub_product classes for our problem. So product classes are more comprehensible.
#
# We might have to drop some of the classes that are not required for our problem or the ones that have null values.

# %% [markdown]
# ##### Extracting relevant columns for our problem

# %%
new_df = df[['product', 'sub_product', 'issue', 'sub_issue', 'narrative']]
new_df.head()
# Out:
#                                              product             sub_product  \
# 0  Credit reporting, credit repair services, or o...        Credit reporting
# 1  Credit reporting, credit repair services, or o...        Credit reporting
# 2                                    Debt collection        Credit card debt
# 3                                           Mortgage  Other type of mortgage
# 4                                    Debt collection              Other debt
#
#                                                issue  \
# 0                        Improper use of your report
# 1  Problem with a credit reporting company's inve...
# 2  Took or threatened to take negative or legal a...
# 3                     Trouble during payment process
# 4                  Attempts to collect debt not owed
#
#                                            sub_issue narrative
# 0      Reporting company used your report improperly       NaN
# 1  Their investigation did not fix an error on yo...       NaN
# 2  Threatened or suggested your credit would be d...       NaN
# 3                                                NaN       NaN
# 4                                  Debt is not yours       NaN

# %%
plotCountPlot(new_df, 'product', 'Product Count', 'Product', 'Count', invert=True)

# %%
# Getting the count of each product
new_df['product'].value_counts()
# Out:
# Credit reporting, credit repair services, or other personal consumer reports    1427733
# Debt collection                                                                  452370
# Mortgage                                                                         365096
# Credit card or prepaid card                                                      165248
# Checking or savings account                                                      141706
# Credit reporting                                                                 140430
# Credit card                                                                       89190
# Bank account or service                                                           86206
# Student loan                                                                      71479
# Money transfer, virtual currency, or money service                                47590
# Vehicle loan or lease                                                             37116
# Consumer Loan                                                                     31596
# Payday loan, title loan, or personal loan                                         25204
# Payday loan                                                                        5543
# Money transfers                                                                    5354
# Prepaid card                                                                       3819
# Other financial service                                                            1058
# Virtual currency                                                                     18
# Name: product, dtype: int64

# %%
# Getting the count of each sub product
new_df['sub_product'].value_counts()
# Out:
# Credit reporting                              1411527
# Checking account                               171328
# General-purpose credit card or charge card     125386
# I do not know                                   98828
# Other mortgage                                  86635
#                                                ...
# Credit repair                                     102
# Traveler’s/Cashier’s checks                        88
# Transit card                                       37
# Student prepaid card                               25
# Electronic Benefit Transfer / EBT card             12
# Name: sub_product, Length: 76, dtype: int64

# %%
# Getting count of issue
new_df['issue'].value_counts()
# Out:
# Incorrect information on your report                                                758841
# Problem with a credit reporting company's investigation into an existing problem    383340
# Improper use of your report                                                         261617
# Attempts to collect debt not owed                                                   152657
# Loan modification,collection,foreclosure                                            112309
#                                                                                      ...
# Property was sold                                                                        9
# Lender damaged or destroyed vehicle                                                      8
# Lender sold the property                                                                 7
# Property was damaged or destroyed property                                               6
# Lender damaged or destroyed property                                                     3
# Name: issue, Length: 165, dtype: int64

# %%
# Getting count of sub issue
new_df['sub_issue'].value_counts()
# Out:
# Information belongs to someone else                                                 486247
# Their investigation did not fix an error on your report                             205995
# Reporting company used your report improperly                                       163025
# Credit inquiries on your report that you don't recognize                             96059
# Account status incorrect                                                             89359
#                                                                                      ...
# Was signed up for overdraft on card, but don't want to be                                6
# Insurance terms                                                                          6
# Problem with a credit reporting company's investigation into an existing problem         3
# Credit monitoring or identity theft protection services                                  1
# Improper use of your report                                                              1
# Name: sub_issue, Length: 221, dtype: int64

# %% [markdown]
# ##### Analysis after seeing the counts:
#
# There is surely a lot of data, but only 'product' seems to have enough data for training. All the other columns are highly imbalanced (even more than 'product') i.e. they have little to no data for some classes.
#
# Also for 'sub_product' there seems to be a large number of ambiguous data as there are classes like 'others', 'i don't know' and 'none'. If I decided to combine the 'product' and 'sub_product', then it might be a challenge as there would be overlaps.

# %% [markdown]
# #### Assessing Null Values

# %%
# List count of null values in each column
print("Count of null values in each column")
print(new_df.isnull().sum())
print("-----------------------")
# List count of all values minus null values in each column
print("Actual count of values in each column excluding null values")
print(new_df.count() - new_df.isnull().sum())
# Out:
# Count of null values in each column
# product              0
# sub_product     235294
# issue                0
# sub_issue       683153
# narrative      1984336
# dtype: int64
# -----------------------
# Actual count of values in each column excluding null values
# product        3096756
# sub_product    2626168
# issue          3096756
# sub_issue      1730450
# narrative      -871916
# dtype: int64

# %%
# Find the percentage of null values in each column
print("Percentage of null values in each column")
print(new_df.isnull().sum() / new_df.shape[0] * 100)
# Out:
# Percentage of null values in each column
# product         0.000000
# sub_product     7.598080
# issue           0.000000
# sub_issue      22.060279
# narrative      64.077893
# dtype: float64

# %%
new_df.shape
# Out:
# (3096756, 5)

# %% [markdown]
# What can we make out of this null values?
#
# Since we are doing text classification, we obviously need text to perform the classification. Mostly the text should have been in the narrative section. But we can see from the above, 'narrative' has 64% of values as NaN.
#
# Since there are 3096756 rows in our data, we can comfortably remove about 64% of our data and still have significant data left for training.

# %% [markdown]
# ##### Dropping the rows where narrative is Null

# %%
# Drop rows where narrative is null
new_df = new_df.dropna(subset=['narrative'])

# %%
new_df.shape
# Out:
# (1112420, 5)

# %%
# Find the percentage of null values in each column
print("Percentage of null values in each column")
print(new_df.isnull().sum() / new_df.shape[0] * 100)
# Out:
# Percentage of null values in each column
# product         0.000000
# sub_product     4.693191
# issue           0.000000
# sub_issue      17.482965
# narrative       0.000000
# dtype: float64

# %% [markdown]
# We still have null values, but the percentage of them has dropped significantly. Now the dataset seems to be workable.

# %% [markdown]
# ##### Working with the text data

# %%
print(new_df.iloc[0])
# Out:
# product                                          Debt collection
# sub_product                                           Other debt
# issue                          Attempts to collect debt not owed
# sub_issue                                          Debt was paid
# narrative      XXXX. I do not owe any money to XXXX  XXXX. I ...
# Name: 38, dtype: object

# %%
narrative_text = new_df['narrative'].iloc[0]
print(narrative_text)
# Out:
# XXXX. I do not owe any money to XXXX  XXXX. I have never received a bill from XXXX indicating a balance due.
# XXXX. I have never received a Demand Letter from XXXX indicating if the amount due is not paid by XXXX date, collection action will begin XXXX. My payments for service are up to date [ no money for service is due ] XXXX. I have returned all equipment to XXXX XXXX for which I received a receipt.!!
# XXXX. XXXX has previously contracted for this with XXXX XXXX XXXX XXXX XXXX, and the XXXX XXXX, to which I provided the receipt and the same above information. It would appear XXXX is engaged in XXXX XXXX XXXX.
# XXXX. I have provided all this information to IC Systems XXXX IC Systems has NOW placed a derogatory item on my credit report.

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\akaid\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\akaid\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ##### Do I need thos function process text?
#
# TfidfVectorizer() should be able to remove the stopwords for me, but I don't know if it can remove the stopwords defined in the function below.

# %%
stopwords_list = stopwords.words('english')
stopwords_list += list(string.punctuation)
stopwords_list += ["XXXX", "xxxx"]

# %%
import re

def process_text(text):
  '''
    Function to process the text and return a list of words with stopwords and punctuations removed
  '''
  tokens = word_tokenize(text)

  # Revove tokens with stop words removed.
  ret_tokens_st = [token.lower() for token in tokens if token.lower() not in stopwords_list]

  # Remove tokens with 2 or more consecutive x's
  for token in ret_tokens_st:
    if re.search(r'x{2,}', token):
        ret_tokens_st.remove(token)

  # Remove tokens with 2 or more consecutive -'s
  for token in ret_tokens_st:
    if re.search(r'-{2,}', token):
        ret_tokens_st.remove(token)

  # Remove tokens with 2 or more consecutive .'s
  for token in ret_tokens_st:
    if re.search(r'\.{2,}', token):
        ret_tokens_st.remove(token)

  # Remove tokens with float numbers
  for token in ret_tokens_st:
    if re.search(r'\d+\.\d+', token):
        ret_tokens_st.remove(token)

  # Remove tokens with date in format xx/xx/xxxxx
  for token in ret_tokens_st:
    if re.search(r'\d+/\d+/\d+', token):
        ret_tokens_st.remove(token)
        
  # Remove tokens with numbers  
  ret_tokens = [token for token in ret_tokens_st if not token.isnumeric()]

  return ret_tokens

# %% [markdown]
# I defined a fucntion to remove the punctuaions and stop words from the string/text passed to it.

# %%
processed = process_text(narrative_text)
print(processed)
# Out:
# ['owe', 'money', 'never', 'received', 'bill', 'indicating', 'balance', 'due', 'never', 'received', 'demand', 'letter', 'indicating', 'amount', 'due', 'paid', 'date', 'collection', 'action', 'begin', 'payments', 'service', 'date', 'money', 'service', 'due', 'returned', 'equipment', 'received', 'receipt.', 'previously', 'contracted', 'provided', 'receipt', 'information', 'would', 'appear', 'engaged', 'provided', 'information', 'ic', 'systems', 'ic', 'systems', 'placed', 'derogatory', 'item', 'credit', 'report']

# %% [markdown]
# Need to add stop words to stop list based on future finds of words like 'xxxx'

# %% [markdown]
# Will try random rows to check if text needs to be filtered more
#
# Things found to filter the text with:
#
# * Consecutive x's
# * Consecutive -'s
# * Consecutive .'s
# * Numbers
# * Float numbers
# * Dates xx/xx/xxxx
#
# Regex for the above have been added to the function to process the narrative.

# %%
# Processed and tokenised words from the first narrative w/ 'xxxx' removed

narrative_text = new_df['narrative'].iloc[15405]

processed = process_text(narrative_text)
print(processed)

# Print the Frequency distribution of words in the first narrative
fdist = FreqDist(processed)

for each in fdist.most_common():
    print(each)
# Out:
# ['get', 'paid', 'first', 'chime', 'wanted', 'see', 'chime', 'trustworthy', 'set', 'make', 'transfer', 'savings', 'buy', 'water', 'since', 'live', 'across', 'lost', 'card', 'hour', 'later', 'get', 'charged', 'know', 'spend', 'water', 'theres', 'way', 'get', 'charged', 'right', 'call', 'chime', 'customer', 'service', 'explain', 'disregarded', 'complaint', 'issue', 'get', 'connected', 'another', 'customer', 'service', 'associate', 'hung', '2nd', 'associate', 'able', 'provide', 'help', 'started', 'dispute', 'submitted', 'timestamps', 'help', 'showing', 'iwas', 'indeed', 'make', 'transaction', 'water', 'home', 'transaction', 'another', 'reason', 'making', 'complaint', 'chime', 'refuses', 'start', 'dispute', 'transfer', 'closed', 'account', 'made', 'im', 'getting', 'continuous', 'emails', 'point', 'new', 'locations', 'devices', 'account', 'accessed', 'wake', 'first', 'instinct', 'check', 'chime', 'account', 'went', 'initial', 'instinct', 'course', 'change', 'password', 'done', 'next', 'day', 'fraudulent', 'atm', 'withdrawal', 'left', 'account', 'transferred', 'chimes', 'savings', 'account', 'entire', 'experience', 'chime', 'left', 'wondering', 'bank', 'security', 'features', 'used', 'satisfied', 'customer', 'fraudulent', 'charges', 'although', 'okay', 'happening', 'becausei', 'know', 'bank', 'back', 'know', 'chime', 'financial', 'service', 'back', 'side', 'help', 'get', 'money', 'back', 'filed', 'police', 'report', 'writing', 'complaint', 'final', 'hope', 'reclaim', 'stolen', 'funds']
# ('chime', 7)
# ('get', 5)
# ('account', 5)
# ('water', 3)
# ('know', 3)
# ('customer', 3)
# ('service', 3)
# ('complaint', 3)
# ('help', 3)
# ('back', 3)
# ('first', 2)
# ('make', 2)
# ('transfer', 2)
# ('savings', 2)
# ('charged', 2)
# ('another', 2)
# ('associate', 2)
# ('dispute', 2)
# ('transaction', 2)
# ('instinct', 2)
# ('fraudulent', 2)
# ('left', 2)
# ('bank', 2)
# ('paid', 1)
# ('wanted', 1)
# ('see', 1)
# ('trustworthy', 1)
# ('set', 1)
# ('buy', 1)
# ('since', 1)
# ('live', 1)
# ('across', 1)
# ('lost', 1)
# ('card', 1)
# ('hour', 1)
# ('later', 1)
# ('spend', 1)
# ('theres', 1)
# ('way', 1)
# ('right', 1)
# ('call', 1)
# ('explain', 1)
# ('disregarded', 1)
# ('issue', 1)
# ('connected', 1)
# ('hung', 1)
# ('2nd', 1)
# ('able', 1)
# ('provide', 1)
# ('started', 1)
# ('submitted', 1)
# ('timestamps', 1)
# ('showing', 1)
# ('iwas', 1)
# ('indeed', 1)
# ('home', 1)
# ('reason', 1)
# ('making', 1)
# ('refuses', 1)
# ('start', 1)
# ('closed', 1)
# ('made', 1)
# ('im', 1)
# ('getting', 1)
# ('continuous', 1)
# ('emails', 1)
# ('point', 1)
# ('new', 1)
# ('locations', 1)
# ('devices', 1)
# ('accessed', 1)
# ('wake', 1)
# ('check', 1)
# ('went', 1)
# ('initial', 1)
# ('course', 1)
# ('change', 1)
# ('password', 1)
# ('done', 1)
# ('next', 1)
# ('day', 1)
# ('atm', 1)
# ('withdrawal', 1)
# ('transferred', 1)
# ('chimes', 1)
# ('entire', 1)
# ('experience', 1)
# ('wondering', 1)
# ('security', 1)
# ('features', 1)
# ('used', 1)
# ('satisfied', 1)
# ('charges', 1)
# ('although', 1)
# ('okay', 1)
# ('happening', 1)
# ('becausei', 1)
# ('financial', 1)
# ('side', 1)
# ('money', 1)
# ('filed', 1)
# ('police', 1)
# ('report', 1)
# ('writing', 1)
# ('final', 1)
# ('hope', 1)
# ('reclaim', 1)
# ('stolen', 1)
# ('funds', 1)

# %%
fdist.plot()
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ##### Data manipulation (combining classes)

# %% [markdown]
# Now that we have the baseline for text processing, we can move on to our previous question.
#
# Possibility 1:
# We have **'issue'**, **'sub_issue'**and **'narrative'** to work with in terms of data to perform classificaiton. So we will try to combine some data, maybe even combine these feautures.
#
# Possibility 2: Try to merge **'products'** rows, as not all of them have satisfactory amount of data.

# %%
# Getting the count of each product
new_df['product'].value_counts()
# Out:
# Credit reporting, credit repair services, or other personal consumer reports    514280
# Debt collection                                                                 191946
# Mortgage                                                                         97748
# Credit card or prepaid card                                                      81787
# Checking or savings account                                                      54190
# Student loan                                                                     32695
# Credit reporting                                                                 31588
# Money transfer, virtual currency, or money service                               26556
# Vehicle loan or lease                                                            19873
# Credit card                                                                      18838
# Bank account or service                                                          14885
# Payday loan, title loan, or personal loan                                        13563
# Consumer Loan                                                                     9470
# Payday loan                                                                       1746
# Money transfers                                                                   1497
# Prepaid card                                                                      1450
# Other financial service                                                            292
# Virtual currency                                                                    16
# Name: product, dtype: int64

# %% [markdown]
# We can look to see if we can merge/remove some of the rows for the 'product' column.
#
# We can definite see that some of the classes/categories seem to be the same. So we will try to look and them and see if we can merge them

# %%
# Get the head of the dataframe where product is 'Virtual Currency'
new_df[new_df['product'] == 'Virtual currency'].head(15)
# Out:
#                   product                   sub_product  \
# 954739   Virtual currency  Domestic (US) money transfer
# 1030892  Virtual currency  Domestic (US) money transfer
# 1064669  Virtual currency  Domestic (US) money transfer
# 1145895  Virtual currency  Domestic (US) money transfer
# 1167936  Virtual currency  Domestic (US) money transfer
# 1215590  Virtual currency  Domestic (US) money transfer
# 1413537  Virtual currency  International money transfer
# 1497255  Virtual currency  Domestic (US) money transfer
# 1787215  Virtual currency  Domestic (US) money transfer
# 1795149  Virtual currency  Domestic (US) money transfer
# 2021681  Virtual currency  Domestic (US) money transfer
# 2209576  Virtual currency  Domestic (US) money transfer
# 2302488  Virtual currency  Domestic (US) money transfer
# 2362867  Virtual currency  Domestic (US) money transfer
# 3060986  Virtual currency  Domestic (US) money transfer
#
#                                          issue sub_issue  \
# 954739                           Fraud or scam       NaN
# 1030892                   Other service issues       NaN
# 1064669                          Fraud or scam       NaN
# 1145895                   Other service issues       NaN
# 1167936                   Other service issues       NaN
# 1215590                          Fraud or scam       NaN
# 1413537                          Fraud or scam       NaN
# 1497255                   Other service issues       NaN
# 1787215                   Other service issues       NaN
# 1795149                   Other service issues       NaN
# 2021681                   Other service issues       NaN
# 2209576  Money was not available when promised       NaN
# 2302488                   Other service issues       NaN
# 2362867               Other transaction issues       NaN
# 3060986                          Fraud or scam       NaN
#
#                                                  narrative
# 954739   Signedup XXXX family members for referrals on ...
# 1030892  Coinbase rep, XXXX has been being an XXXX to m...
# 1064669  Signed up with Coinbase.com with a {$75.00} si...
# 1145895  Signed up with Coinbase.com with a {$75.00} si...
# 1167936  Two weeks ago my accounts with Coinbase were l...
# 1215590  Signed up with Coinbase.com with a {$75.00} si...
# 1413537  Hi, on XXXX XXXX, I paid XXXX $ in XXXX to my ...
# 1497255  I opened an online account with Coinbase to pu...
# 1787215  I first initiated a support ticket trying to r...
# 1795149  Coinbase account closed without reasonable exp...
# 2021681  I received a random notice 3 days ago from a d...
# 2209576  Hi, I purchased bitcoins from a website coinba...
# 2302488  I applied for an account on " Circle '' and th...
# 2362867  My husband opened an account with Coinbase, an...
# 3060986  Signed up with Coinbase.com with a {$75.00} si...

# %%
# Get the head of the dataframe where product is 'Money transfers, virtual currency, or money service'
new_df[new_df['product'] == 'Money transfer, virtual currency, or money service'].head(15)
# Out:
#                                                  product  \
# 1179   Money transfer, virtual currency, or money ser...
# 4398   Money transfer, virtual currency, or money ser...
# 5393   Money transfer, virtual currency, or money ser...
# 6681   Money transfer, virtual currency, or money ser...
# 7733   Money transfer, virtual currency, or money ser...
# 8074   Money transfer, virtual currency, or money ser...
# 8678   Money transfer, virtual currency, or money ser...
# 8865   Money transfer, virtual currency, or money ser...
# 9192   Money transfer, virtual currency, or money ser...
# 9578   Money transfer, virtual currency, or money ser...
# 10072  Money transfer, virtual currency, or money ser...
# 10195  Money transfer, virtual currency, or money ser...
# 11120  Money transfer, virtual currency, or money ser...
# 11553  Money transfer, virtual currency, or money ser...
# 12213  Money transfer, virtual currency, or money ser...
#
#                                sub_product  \
# 1179          Domestic (US) money transfer
# 4398                 Check cashing service
# 5393          Domestic (US) money transfer
# 6681   Traveler's check or cashier's check
# 7733          Domestic (US) money transfer
# 8074              Mobile or digital wallet
# 8678          International money transfer
# 8865              Mobile or digital wallet
# 9192              Mobile or digital wallet
# 9578          Domestic (US) money transfer
# 10072         International money transfer
# 10195                     Virtual currency
# 11120  Traveler's check or cashier's check
# 11553         Domestic (US) money transfer
# 12213         Domestic (US) money transfer
#
#                                                    issue sub_issue  \
# 1179               Money was not available when promised       NaN
# 4398                            Unexpected or other fees       NaN
# 5393                           Other transaction problem       NaN
# 6681                    Confusing or missing disclosures       NaN
# 7733                                       Fraud or scam       NaN
# 8074                                       Fraud or scam       NaN
# 8678                           Other transaction problem       NaN
# 8865                                       Fraud or scam       NaN
# 9192   Unauthorized transactions or other transaction...       NaN
# 9578                                       Fraud or scam       NaN
# 10072                          Other transaction problem       NaN
# 10195                                      Fraud or scam       NaN
# 11120                      Problem with customer service       NaN
# 11553                          Other transaction problem       NaN
# 12213                                      Fraud or scam       NaN
#
#                                                narrative
# 1179   Northern Trust Bank resigned as Trustee of my ...
# 4398   The company called Plastiq was supposed XXXX a...
# 5393   Under the oath I told Wells Fargo all XXXX tra...
# 6681   Wells Fargo are not complying with Regulation ...
# 7733   On XXXX XXXX, XXXX, I had an appointment with ...
# 8074   I am a victim of XXXX scam. I received a text ...
# 8678   Dear Sir/Madame, At XXXX of XXXX I send the pa...
# 8865   XX/XX/22 -- XXXX fraudulent claim was made wit...
# 9192   I was a beneficiary for an account which was w...
# 9578   I was involved in a scam where I lost over {$8...
# 10072  On XX/XX/2022 I went to my bank CiTI bank to m...
# 10195  Commencing on or about XX/XX/2022, I fell vict...
# 11120  On XX/XX/XXXX I received a officials cashiers ...
# 11553  XXXX checks were sent to pay my XXXX accounts ...
# 12213  I have an account with Bank of America and XXX...

# %%
# Get the head of the dataframe where product is 'Money transfers'
new_df[new_df['product'] == 'Money transfers'].head(15)
# Out:
#                 product                   sub_product  \
# 52304   Money transfers  Domestic (US) money transfer
# 53109   Money transfers  International money transfer
# 102073  Money transfers  International money transfer
# 104315  Money transfers  International money transfer
# 104382  Money transfers  Domestic (US) money transfer
# 106152  Money transfers  International money transfer
# 106258  Money transfers  Domestic (US) money transfer
# 106617  Money transfers  International money transfer
# 106797  Money transfers  Domestic (US) money transfer
# 106829  Money transfers  Domestic (US) money transfer
# 107149  Money transfers  Domestic (US) money transfer
# 107197  Money transfers  Domestic (US) money transfer
# 107726  Money transfers  Domestic (US) money transfer
# 108368  Money transfers  Domestic (US) money transfer
# 108575  Money transfers  International money transfer
#
#                                         issue sub_issue  \
# 52304                Other transaction issues       NaN
# 53109                Other transaction issues       NaN
# 102073               Other transaction issues       NaN
# 104315  Money was not available when promised       NaN
# 104382               Other transaction issues       NaN
# 106152  Money was not available when promised       NaN
# 106258               Other transaction issues       NaN
# 106617               Other transaction issues       NaN
# 106797                          Fraud or scam       NaN
# 106829                          Fraud or scam       NaN
# 107149                          Fraud or scam       NaN
# 107197  Money was not available when promised       NaN
# 107726  Money was not available when promised       NaN
# 108368               Other transaction issues       NaN
# 108575               Other transaction issues       NaN
#
#                                                 narrative
# 52304   XX/XX/XXXX one of my sons asked me to pay his ...
# 53109   My name is XXXX and I have been doing transact...
# 102073  Hi There, Thanks for the giving an opportunity...
# 104315  I did a international transfer on XX/XX/2016 o...
# 104382  On XX/XX/2016 Paypal limited my account due to...
# 106152  I made a wire transfer through Citibank to XXX...
# 106258  I purchased a money order on XX/XX/2016 ( to c...
# 106617  Describe what happened so we can understand th...
# 106797  I received a phone call from XXXX stating that...
# 106829  I paid by bank wire transfer on XXXX/XXXX/XXXX...
# 107149  Our company XXXX XXXX XXXX XXXX, Receive custo...
# 107197  I have linked an external bank account with my...
# 107726  Paypal restricted my accts after i provided in...
# 108368  I initiated a transfer of funds from two CD IR...
# 108575  Created an account with Viamericas to transfer...

# %% [markdown]
# Now to check for all loans.

# %%
# Get the head of the dataframe where product is 'Student loans'
new_df[new_df['product'] == 'Student loan'].head(15)
# Out:
#             product                     sub_product  \
# 5058   Student loan            Private student loan
# 10236  Student loan            Private student loan
# 10432  Student loan            Private student loan
# 19643  Student loan  Federal student loan servicing
# 20102  Student loan            Private student loan
# 20798  Student loan  Federal student loan servicing
# 24445  Student loan  Federal student loan servicing
# 25107  Student loan            Private student loan
# 26925  Student loan            Private student loan
# 27924  Student loan            Private student loan
# 34079  Student loan            Private student loan
# 34094  Student loan            Private student loan
# 34152  Student loan            Private student loan
# 34175  Student loan  Federal student loan servicing
# 35777  Student loan  Federal student loan servicing
#
#                                       issue  \
# 5058          Struggling to repay your loan
# 10236         Struggling to repay your loan
# 10432  Dealing with your lender or servicer
# 19643  Dealing with your lender or servicer
# 20102  Dealing with your lender or servicer
# 20798  Dealing with your lender or servicer
# 24445           Improper use of your report
# 25107         Struggling to repay your loan
# 26925  Dealing with your lender or servicer
# 27924  Dealing with your lender or servicer
# 34079         Struggling to repay your loan
# 34094                        Getting a loan
# 34152  Dealing with your lender or servicer
# 34175  Dealing with your lender or servicer
# 35777  Dealing with your lender or servicer
#
#                                                sub_issue  \
# 5058              Problem lowering your monthly payments
# 10236            Can't temporarily delay making payments
# 10432  Need information about your loan balance or lo...
# 19643                 Keep getting calls about your loan
# 20102        Trouble with how payments are being handled
# 20798           Received bad information about your loan
# 24445  Report provided to employer without your writt...
# 25107  Can't get other flexible options for repaying ...
# 26925                      Problem with customer service
# 27924           Received bad information about your loan
# 34079             Problem lowering your monthly payments
# 34094                                    Fraudulent loan
# 34152        Trouble with how payments are being handled
# 34175  Need information about your loan balance or lo...
# 35777           Received bad information about your loan
#
#                                                narrative
# 5058   XX/XX/2022 - Predatory lender. I contacted Sal...
# 10236  I have been attempting to resolve issues of pa...
# 10432  I co-signed on a private student loan through ...
# 19643  Hi! \nI think I was scammed. \n\nI got a call ...
# 20102  Misapplication of a payment led to charge-off ...
# 20798  Ive had FFELP loans serviced by American educa...
# 24445  In accordance with the fair Credit Reporting a...
# 25107  I have called numerous times complaining about...
# 26925  XXXX XXXX XXXX from Wells Fargo Enterprise Com...
# 27924  I have recently been educated about the Consum...
# 34079  I am a single mother and work full time for th...
# 34094  I am filing this complaint because Wells Fargo...
# 34152  To be honest I really want to sue Navient. I f...
# 34175  InXX/XX/XXXX, I received loans for my online g...
# 35777  After I submitted my IBR annual re-certificati...

# %%
# Get the head of the dataframe where product is 'Vehicle loan or lease'
new_df[new_df['product'] == 'Vehicle loan or lease'].head(15)
# Out:
#                      product sub_product  \
# 3186   Vehicle loan or lease        Loan
# 3767   Vehicle loan or lease        Loan
# 3839   Vehicle loan or lease        Loan
# 5227   Vehicle loan or lease        Loan
# 5458   Vehicle loan or lease       Lease
# 6002   Vehicle loan or lease        Loan
# 6938   Vehicle loan or lease       Lease
# 7822   Vehicle loan or lease        Loan
# 8964   Vehicle loan or lease       Lease
# 9906   Vehicle loan or lease        Loan
# 10372  Vehicle loan or lease       Lease
# 10737  Vehicle loan or lease        Loan
# 11385  Vehicle loan or lease        Loan
# 12942  Vehicle loan or lease        Loan
# 14429  Vehicle loan or lease        Loan
#
#                                           issue  \
# 3186                Struggling to pay your loan
# 3767                Struggling to pay your loan
# 3839                 Managing the loan or lease
# 5227                 Managing the loan or lease
# 5458                 Managing the loan or lease
# 6002   Problems at the end of the loan or lease
# 6938   Problems at the end of the loan or lease
# 7822                 Managing the loan or lease
# 8964   Problems at the end of the loan or lease
# 9906   Problems at the end of the loan or lease
# 10372  Problems at the end of the loan or lease
# 10737                Managing the loan or lease
# 11385                   Getting a loan or lease
# 12942                Managing the loan or lease
# 14429                Managing the loan or lease
#
#                                                sub_issue  \
# 3186                    Denied request to lower payments
# 3767   Lender trying to repossess or disable the vehicle
# 3839                      Problem with the interest rate
# 5227   Problem with additional products or services p...
# 5458   Problem with additional products or services p...
# 6002      Problem while selling or giving up the vehicle
# 6938   Termination fees or other problem when ending ...
# 7822   Problem with additional products or services p...
# 8964                    Problem with paying off the loan
# 9906                    Problem with paying off the loan
# 10372  Problem when attempting to purchase vehicle at...
# 10737                                    Billing problem
# 11385                                    Fraudulent loan
# 12942  Problem with additional products or services p...
# 14429                                    Billing problem
#
#                                                narrative
# 3186   They are calling excessively- a minimum of fiv...
# 3767   XXXX caused me to get behind, Where I work eve...
# 3839   According to my consumer profile this alleged ...
# 5227   Hi, We are a repair facility and XXXX XXXX and...
# 5458   Date : XX/XX/XXXX XXXX XXXX XXXX XXXX XXXX XXX...
# 6002   The car was paid off back in XXXX and I ask th...
# 6938   I want to take those hard pull of my credit re...
# 7822   I brought my car from XXXX XXXX XXXX in XXXX G...
# 8964   Leased vehicle was totaled XX/XX/2022. Vehicle...
# 9906   I purchased a XXXX XXXX XXXX from XXXX XXXX XX...
# 10372  On XX/XX/XXXX I overnighted a check to pay off...
# 10737  In accordance with the FCRA, Westlake Financia...
# 11385  I XXXX : XXXX reached out concerning a transac...
# 12942  XX/XX/XXXX I submitted my documentation to obt...
# 14429  I recently purchased a new vehicle and my loan...

# %%
# Get the head of the dataframe where product is 'Payday loan, title loan, or personal loan'
new_df[new_df['product'] == 'Payday loan, title loan, or personal loan'].head(15)
# Out:
#                                          product              sub_product  \
# 4729   Payday loan, title loan, or personal loan              Payday loan
# 7129   Payday loan, title loan, or personal loan              Payday loan
# 7832   Payday loan, title loan, or personal loan         Installment loan
# 8948   Payday loan, title loan, or personal loan               Title loan
# 9088   Payday loan, title loan, or personal loan  Personal line of credit
# 10518  Payday loan, title loan, or personal loan              Payday loan
# 10648  Payday loan, title loan, or personal loan         Installment loan
# 11377  Payday loan, title loan, or personal loan         Installment loan
# 11520  Payday loan, title loan, or personal loan         Installment loan
# 12591  Payday loan, title loan, or personal loan         Installment loan
# 13443  Payday loan, title loan, or personal loan              Payday loan
# 14115  Payday loan, title loan, or personal loan              Payday loan
# 15772  Payday loan, title loan, or personal loan  Personal line of credit
# 16893  Payday loan, title loan, or personal loan         Installment loan
# 19191  Payday loan, title loan, or personal loan         Installment loan
#
#                                                    issue  \
# 4729                Received a loan you didn't apply for
# 7129   Money was taken from your bank account on the ...
# 7832          Charged fees or interest you didn't expect
# 8948                Incorrect information on your report
# 9088                            Getting a line of credit
# 10518         Charged fees or interest you didn't expect
# 10648               Incorrect information on your report
# 11377                                   Getting the loan
# 11520                       Problem when making payments
# 12591                        Struggling to pay your loan
# 13443  Was approved for a loan, but didn't receive th...
# 14115  Problem with the payoff process at the end of ...
# 15772         Charged fees or interest you didn't expect
# 16893  Problem with the payoff process at the end of ...
# 19191               Incorrect information on your report
#
#                                   sub_issue  \
# 4729                                    NaN
# 7129                                    NaN
# 7832                                    NaN
# 8948          Account information incorrect
# 9088                                    NaN
# 10518                                   NaN
# 10648              Account status incorrect
# 11377                                   NaN
# 11520                                   NaN
# 12591                                   NaN
# 13443                                   NaN
# 14115                                   NaN
# 15772                                   NaN
# 16893                                   NaN
# 19191  Public record information inaccurate
#
#                                                narrative
# 4729   XX/XX/XXXX - I applied for a loan online based...
# 7129   On XX/XX/22 XXXX XXXX XXXX was NOT authorized ...
# 7832   I thought this app would help they promise to ...
# 8948   My auto loan is showing that my payments we're...
# 9088   I am a victim of XXXX scam. I received a text ...
# 10518  Hello XXXX Case No : XXXX After receiving this...
# 10648  My military loan with Omni Financial was sent ...
# 11377  Summary : Perfect 'Bait and Switch " Wells Far...
# 11520  I am having an ongoing issue with my payment s...
# 12591  Back in XX/XX/2022 I got XXXX XXXX I behind in...
# 13443  I was approved then blocked and denied after c...
# 14115  I got a loan from Speedy Cash in Colorado, due...
# 15772  United Community Bank engaged in unfair and de...
# 16893  A few years back, my son was diagnosed with XX...
# 19191  We got a loan for solar panels in 2016. The co...

# %% [markdown]
# All these three look to be the same or at least similar. So we can safely merge these three categeories and since 'virtual currencies' has very low data, it is better to merge it anyways.

# %%
new_df['product'].replace({'Virtual currency':'Money_and_virtual_transfers_and_services',
'Money transfer, virtual currency, or money service':'Money_and_virtual_transfers_and_services',
 'Money transfers': 'Money_and_virtual_transfers_and_services'}, inplace=True)

# %%
new_df['product'].value_counts()
# Out:
# Credit reporting, credit repair services, or other personal consumer reports    514280
# Debt collection                                                                 191946
# Mortgage                                                                         97748
# Credit card or prepaid card                                                      81787
# Checking or savings account                                                      54190
# Student loan                                                                     32695
# Credit reporting                                                                 31588
# Money_and_virtual_transfers_and_services                                         28069
# Vehicle loan or lease                                                            19873
# Credit card                                                                      18838
# Bank account or service                                                          14885
# Payday loan, title loan, or personal loan                                        13563
# Consumer Loan                                                                     9470
# Payday loan                                                                       1746
# Prepaid card                                                                      1450
# Other financial service                                                            292
# Name: product, dtype: int64

# %% [markdown]
# We can safely merge the loans as there is not a lot of data in some of the 'xxxxx_loan' categeories. This would help in classifying as we combined and have more data for the 'loan' category.

# %%
new_df['product'].replace({'Student loan':'loans',
'Vehicle loan or lease':'loans',
 'Payday loan, title loan, or personal loan': 'loans',
 'Consumer Loan':'loans',
 'Payday loan':'loans',}, inplace=True)

# %%
new_df['product'].value_counts()
# Out:
# Credit reporting, credit repair services, or other personal consumer reports    514280
# Debt collection                                                                 191946
# Mortgage                                                                         97748
# Credit card or prepaid card                                                      81787
# loans                                                                            77347
# Checking or savings account                                                      54190
# Credit reporting                                                                 31588
# Money_and_virtual_transfers_and_services                                         28069
# Credit card                                                                      18838
# Bank account or service                                                          14885
# Prepaid card                                                                      1450
# Other financial service                                                            292
# Name: product, dtype: int64

# %% [markdown]
# Similarly, we can merge all similar to credit reporting ('Credit reporting, credit repair services, or other personal consumer reports' and 'Credit Reporting')

# %%
new_df['product'].replace({'Credit reporting, credit repair services, or other personal consumer reports':'credit_reporting_and_services',
'Credit reporting':'credit_reporting_and_services'}, inplace=True)
new_df['product'].value_counts()
# Out:
# credit_reporting_and_services               545868
# Debt collection                             191946
# Mortgage                                     97748
# Credit card or prepaid card                  81787
# loans                                        77347
# Checking or savings account                  54190
# Money_and_virtual_transfers_and_services     28069
# Credit card                                  18838
# Bank account or service                      14885
# Prepaid card                                  1450
# Other financial service                        292
# Name: product, dtype: int64

# %% [markdown]
# Trying to figure out what 'Other financial service' are about...

# %%
# Get the head of the dataframe where product is 'Other financial service'
new_df[new_df['product'] == 'Other financial service'].head(15)
# Out:
#                         product                sub_product  \
# 98954   Other financial service            Debt settlement
# 115764  Other financial service              Credit repair
# 131541  Other financial service            Debt settlement
# 135664  Other financial service              Check cashing
# 136603  Other financial service            Debt settlement
# 136785  Other financial service  Foreign currency exchange
# 142385  Other financial service                Money order
# 157977  Other financial service            Debt settlement
# 403743  Other financial service              Check cashing
# 602776  Other financial service                Money order
# 603048  Other financial service            Debt settlement
# 604551  Other financial service            Debt settlement
# 606419  Other financial service            Debt settlement
# 607739  Other financial service              Check cashing
# 755504  Other financial service              Check cashing
#
#                                       issue sub_issue  \
# 98954                         Fraud or scam       NaN
# 115764                        Fraud or scam       NaN
# 131541                        Fraud or scam       NaN
# 135664  Customer service/Customer relations       NaN
# 136603  Customer service/Customer relations       NaN
# 136785  Customer service/Customer relations       NaN
# 142385                Unexpected/Other fees       NaN
# 157977                          Disclosures       NaN
# 403743                Unexpected/Other fees       NaN
# 602776                        Fraud or scam       NaN
# 603048                        Fraud or scam       NaN
# 604551                        Fraud or scam       NaN
# 606419                        Fraud or scam       NaN
# 607739                       Excessive fees       NaN
# 755504                        Fraud or scam       NaN
#
#                                                 narrative
# 98954   i hired Pay map company to collect my mortgage...
# 115764  Since using the service it appears my credit i...
# 131541  A company by the name of student loan relief d...
# 135664  Certegy XXXX XXXX has a file of my name and an...
# 136603  HELLO, Re : Account # XXXX I have called asked...
# 136785  I am submitting a complaint in regards to a ba...
# 142385  I purchased a WU Money Order for {$75.00} to m...
# 157977  Contract is misleading advising you can get a ...
# 403743  Dear CFPB, I contacted Bank of America to clos...
# 602776  On XXXX/XXXX/16, I purchased XXXX moneygram mo...
# 603048  I hired Shoreview Financial XX/XX/2014 to modi...
# 604551  About a month ago ( XX/XX/XXXX ) I was contact...
# 606419  I was told that I pay them a certain amount an...
# 607739  I was inaccurately informed about how a bank w...
# 755504  I XXXX XXXX cashed a check from my XXXX XXXX a...

# %% [markdown]
# Since the columns 'Other financial service', 'Bank account or service', 'Checking or savings account' seem to bew similar, we will merge them

# %%
new_df['product'].replace({'Other financial service':'banking_services',
'Bank account or service':'banking_services',
'Checking or savings account':'banking_services',}, inplace=True)
new_df['product'].value_counts()
# Out:
# credit_reporting_and_services               545868
# Debt collection                             191946
# Mortgage                                     97748
# Credit card or prepaid card                  81787
# loans                                        77347
# banking_services                             69367
# Money_and_virtual_transfers_and_services     28069
# Credit card                                  18838
# Prepaid card                                  1450
# Name: product, dtype: int64

# %% [markdown]
# Since the columns 'Prepaid card', 'Credit card', 'Credit card or prepaid card' seem to bew similar, we will merge them

# %%
new_df['product'].replace({'Prepaid card':'credit_card_or_prepaid_card',
'Credit card':'credit_card_or_prepaid_card',
'Credit card or prepaid card':'credit_card_or_prepaid_card'}, inplace=True)
new_df['product'].value_counts()
# Out:
# credit_reporting_and_services               545868
# Debt collection                             191946
# credit_card_or_prepaid_card                 102075
# Mortgage                                     97748
# loans                                        77347
# banking_services                             69367
# Money_and_virtual_transfers_and_services     28069
# Name: product, dtype: int64

# %%
new_df['product'].replace({'Debt collection':'debt_collection'}, inplace=True)
new_df['product'].value_counts()
# Out:
# credit_reporting_and_services               545868
# debt_collection                             191946
# credit_card_or_prepaid_card                 102075
# Mortgage                                     97748
# loans                                        77347
# banking_services                             69367
# Money_and_virtual_transfers_and_services     28069
# Name: product, dtype: int64

# %%
plotCountPlot(new_df, 'product', 'Product Count', 'Count', 'Product', invert=True)

# %% [markdown]
# Data still seems to be imbalanced, but certainly better than before. Maybe I can try to marge more 'product' categories to be able to get decent data for classification.

# %%
# Get the head of the dataframe where product is 'Mortgage'
new_df[new_df['product'] == 'Mortgage'].head(15)
# Out:
#        product                 sub_product  \
# 308   Mortgage                FHA mortgage
# 450   Mortgage                 VA mortgage
# 745   Mortgage  Conventional home mortgage
# 2059  Mortgage  Conventional home mortgage
# 2220  Mortgage                FHA mortgage
# 2417  Mortgage                FHA mortgage
# 3267  Mortgage  Conventional home mortgage
# 3583  Mortgage  Conventional home mortgage
# 3588  Mortgage                FHA mortgage
# 3613  Mortgage  Conventional home mortgage
# 3659  Mortgage  Conventional home mortgage
# 3864  Mortgage  Conventional home mortgage
# 3929  Mortgage                 VA mortgage
# 4057  Mortgage  Conventional home mortgage
# 4639  Mortgage  Conventional home mortgage
#
#                                                   issue sub_issue  \
# 308                          Struggling to pay mortgage       NaN
# 450   Applying for a mortgage or refinancing an exis...       NaN
# 745                      Trouble during payment process       NaN
# 2059                     Trouble during payment process       NaN
# 2220  Applying for a mortgage or refinancing an exis...       NaN
# 2417                         Struggling to pay mortgage       NaN
# 3267                     Trouble during payment process       NaN
# 3583                         Struggling to pay mortgage       NaN
# 3588                     Trouble during payment process       NaN
# 3613                         Struggling to pay mortgage       NaN
# 3659                         Struggling to pay mortgage       NaN
# 3864                     Trouble during payment process       NaN
# 3929                         Struggling to pay mortgage       NaN
# 4057                     Trouble during payment process       NaN
# 4639                     Trouble during payment process       NaN
#
#                                               narrative
# 308   Ditech/ShellpointXXXX XXXX XXXX XXXX worked to...
# 450   I applied for a VA XXXX loan with New day USA....
# 745   I have fully paid up my mortgage dues and Sele...
# 2059  Mortgage transfer from XXXX  XXXX  to Truist, ...
# 2220  Approved for a fha loan paid earnest money hom...
# 2417  They have refused a check from the state HAF p...
# 3267  In XXXX I received a notice that our property ...
# 3583  Defaulted on loan, worked with mortgage compan...
# 3588  My mortgage payments are currently being proce...
# 3613  Cfpb disappointed in your level of service & s...
# 3659  In XXXX I received a modification from my mort...
# 3864  I have inquired about paying my own taxes and ...
# 3929  1. On XX/XX/XXXX, my former husband applied fo...
# 4057  This is a folllow up to a previous complaint t...
# 4639  I received Shellpoint package of letters stati...

# %%
# Get the head of the dataframe where product is 'loans'
new_df[new_df['product'] == 'loans'].head(15)
# Out:
#      product              sub_product  \
# 3186   loans                     Loan
# 3767   loans                     Loan
# 3839   loans                     Loan
# 4729   loans              Payday loan
# 5058   loans     Private student loan
# 5227   loans                     Loan
# 5458   loans                    Lease
# 6002   loans                     Loan
# 6938   loans                    Lease
# 7129   loans              Payday loan
# 7822   loans                     Loan
# 7832   loans         Installment loan
# 8948   loans               Title loan
# 8964   loans                    Lease
# 9088   loans  Personal line of credit
#
#                                                   issue  \
# 3186                        Struggling to pay your loan
# 3767                        Struggling to pay your loan
# 3839                         Managing the loan or lease
# 4729               Received a loan you didn't apply for
# 5058                      Struggling to repay your loan
# 5227                         Managing the loan or lease
# 5458                         Managing the loan or lease
# 6002           Problems at the end of the loan or lease
# 6938           Problems at the end of the loan or lease
# 7129  Money was taken from your bank account on the ...
# 7822                         Managing the loan or lease
# 7832         Charged fees or interest you didn't expect
# 8948               Incorrect information on your report
# 8964           Problems at the end of the loan or lease
# 9088                           Getting a line of credit
#
#                                               sub_issue  \
# 3186                   Denied request to lower payments
# 3767  Lender trying to repossess or disable the vehicle
# 3839                     Problem with the interest rate
# 4729                                                NaN
# 5058             Problem lowering your monthly payments
# 5227  Problem with additional products or services p...
# 5458  Problem with additional products or services p...
# 6002     Problem while selling or giving up the vehicle
# 6938  Termination fees or other problem when ending ...
# 7129                                                NaN
# 7822  Problem with additional products or services p...
# 7832                                                NaN
# 8948                      Account information incorrect
# 8964                   Problem with paying off the loan
# 9088                                                NaN
#
#                                               narrative
# 3186  They are calling excessively- a minimum of fiv...
# 3767  XXXX caused me to get behind, Where I work eve...
# 3839  According to my consumer profile this alleged ...
# 4729  XX/XX/XXXX - I applied for a loan online based...
# 5058  XX/XX/2022 - Predatory lender. I contacted Sal...
# 5227  Hi, We are a repair facility and XXXX XXXX and...
# 5458  Date : XX/XX/XXXX XXXX XXXX XXXX XXXX XXXX XXX...
# 6002  The car was paid off back in XXXX and I ask th...
# 6938  I want to take those hard pull of my credit re...
# 7129  On XX/XX/22 XXXX XXXX XXXX was NOT authorized ...
# 7822  I brought my car from XXXX XXXX XXXX in XXXX G...
# 7832  I thought this app would help they promise to ...
# 8948  My auto loan is showing that my payments we're...
# 8964  Leased vehicle was totaled XX/XX/2022. Vehicle...
# 9088  I am a victim of XXXX scam. I received a text ...

# %% [markdown]
# The categories 'loan' and 'mortgage' seem to be similar, but they are different enough to have their own categories. So, will not be merging them.
#
#
# But we can see that 'Money_and_virtual_transfers_and_services' has quite a low count, which would cause problems for training for classification. So it would be appropriate to merge them into 'banking_services'

# %%
new_df['product'].replace({'Money_and_virtual_transfers_and_services':'banking_services_and_transfers',
'banking_services':'banking_services_and_transfers'}, inplace=True)
new_df['product'].value_counts()
# Out:
# credit_reporting_and_services     545868
# debt_collection                   191946
# credit_card_or_prepaid_card       102075
# Mortgage                           97748
# banking_services_and_transfers     97436
# loans                              77347
# Name: product, dtype: int64

# %%
plotCountPlot(new_df, 'product', 'Product Count', 'Count', 'Product', invert=True)

# %% [markdown]
# We can see that the new data is more appropriate for classification problem because the mimimum count for a 'product' category is around 77000 and for data with more than a million entries, that is relatively enough for a classification problem, at least better than the 'product' classes  with close to 700 counts that we had before.
#
# So, at least at this point, we can assume that we have enough data to learn.

# %%
# Get the head 
new_df.head(15)
# Out:
#                             product       sub_product  \
# 38                  debt_collection        Other debt
# 39                  debt_collection        Other debt
# 41    credit_reporting_and_services  Credit reporting
# 68   banking_services_and_transfers   Savings account
# 129   credit_reporting_and_services  Credit reporting
# 137  banking_services_and_transfers  Checking account
# 149   credit_reporting_and_services  Credit reporting
# 150   credit_reporting_and_services  Credit reporting
# 156   credit_reporting_and_services  Credit reporting
# 157   credit_reporting_and_services  Credit reporting
# 265   credit_reporting_and_services  Credit reporting
# 303                 debt_collection     I do not know
# 308                        Mortgage      FHA mortgage
# 339                 debt_collection         Auto debt
# 450                        Mortgage       VA mortgage
#
#                                                  issue  \
# 38                   Attempts to collect debt not owed
# 39                  False statements or representation
# 41                         Improper use of your report
# 68                                 Managing an account
# 129                        Improper use of your report
# 137  Problem with a lender or other company chargin...
# 149               Incorrect information on your report
# 150  Problem with a credit reporting company's inve...
# 156  Problem with a credit reporting company's inve...
# 157               Incorrect information on your report
# 265  Problem with a credit reporting company's inve...
# 303                  Attempts to collect debt not owed
# 308                         Struggling to pay mortgage
# 339                 False statements or representation
# 450  Applying for a mortgage or refinancing an exis...
#
#                                              sub_issue  \
# 38                                       Debt was paid
# 39   Indicated you were committing crime by not pay...
# 41   Credit inquiries on your report that you don't...
# 68                            Deposits and withdrawals
# 129      Reporting company used your report improperly
# 137                     Transaction was not authorized
# 149                Information belongs to someone else
# 150  Their investigation did not fix an error on yo...
# 156  Their investigation did not fix an error on yo...
# 157                Information belongs to someone else
# 265  Their investigation did not fix an error on yo...
# 303                                  Debt is not yours
# 308                                                NaN
# 339  Indicated you were committing crime by not pay...
# 450                                                NaN
#
#                                              narrative
# 38   XXXX. I do not owe any money to XXXX  XXXX. I ...
# 39   XXXX is attempting to collect funds for Valuat...
# 41   EXPERIAN I didnt consent to these Inquiries Al...
# 68   Citibank froze my account that contained {$200...
# 129  In accordance with the fair credit reporting a...
# 137  I had a checking account in this bank for over...
# 149  This is not a duplicate nor is this complaint ...
# 150  It has come to my attention. That my personal ...
# 156  The Federal Trade Commission Bureau of Consume...
# 157  The following creditors, XXXX XXXXXXXX XXXX, a...
# 265  Westlake Portfolio Mgm Westlake Portfolio Mgm ...
# 303  The consumer, who is a federally protected con...
# 308  Ditech/ShellpointXXXX XXXX XXXX XXXX worked to...
# 339  This auto loan is in error, as my Wife passed ...
# 450  I applied for a VA XXXX loan with New day USA....

# %%
# Writing the data to csv file
new_df.to_csv('data/cleaned_complaints.csv', index=False)

# %%
# Get null values in the dataframe
new_df.isnull().sum()
# Out:
# product             0
# sub_product     52208
# issue               0
# sub_issue      194484
# narrative           0
# dtype: int64
