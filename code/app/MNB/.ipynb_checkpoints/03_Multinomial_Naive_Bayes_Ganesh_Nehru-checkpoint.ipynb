# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import preprocessing
import string
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
import seaborn as sb
import missingno as msno
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
#Read new processed complaint data set.
ndf = pd.read_csv('processed_complaints.csv')

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# /var/folders/3n/y6l_g9s960lc_759jvhdhxp40000gn/T/ipykernel_7230/3652881321.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# # Initial data analysis.

# %%
#Examining dataframe.
ndf
# Out:
#          Unnamed: 0                        Product  \
# 0        38          Debt Collection
# 1        39          Debt Collection
# 2        41          Credit Reporting and Services
# 3        68          Banking Services
# 4        129         Credit Reporting and Services
# ...      ...                                   ...
# 1112415  3096750     Credit/Prepaid Cards
# 1112416  3096751     Debt Collection
# 1112417  3096752     Mortgages
# 1112418  3096753     Credit Reporting and Services
# 1112419  3096754     Credit Reporting and Services
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Complaint
# 0        owe money never received bill indicating balance due never received demand letter indicating amount due paid date collection action begin payment service date money service due returned equipment received previously contracted provided receipt information would appear engaged provided information ic system ic system placed derogatory item credit report
# 1        attempting collect fund valuation service provided see responded false allegation requested supporting documentation appraisal provided attempted withdraw business owes account unsuccessful added returned item fee balance owed new total owed due immediately youve already sent payment ignore notice business pay call u pay phone credit card check question also chat u click upload completed payment coupon using secure portal business ca pay full amount call chat u talk option also get help managing business payment account merchant service center thanks account business name case number
# 2        experian didnt consent inquiry also name incorrect address wrong correct information ga title b false activity without written consent title usc without written consent considered identity theft tile usc didnt notify activity still
# 3        citibank froze account contained time make college tuition payment daughter reason result forced make payment incur processing fee college paid credit card instead transfer checking account
# 4        accordance fair credit reporting act account violated section state right privacy section section state consumer reporting company furnish account without written instruction never given
# ...                                                                                                                                                                                             ...
# 1112415  automated call capital one call home phone excessively time day claiming offer solution credit problem account delinquent current never late missed called request number removed registered call list recent call history
# 1112416  disputed debt several time resolution submitted paperwork affidavit police report need resolution account fraud
# 1112417  father died left son belonging also single mother ex wife since remained friend stayed house last year life help care mother unknown time presenting al father creditor wife father right death made clear agreeable presented anyone husband wife regarding mother reason upon time father death family living leased home mother qualified received father social security since married year stayed house made payment family able complete lease home move father home wanted completed probate since father single mother moved home started taking payment laid work initally contacted mortgage company informed unable speak record mother righful owner house since father passed explain wife sent correlative document asked deferrment payment said mortgage holder next started transferring account different location servicing center time would go whole explanation send documentation sending documentation corporate office speaking point set auto withdrawal would go account system wanted withdraw salary deposit account point would take check requesting modification loan time account transferred new servicing center employee would tell send voided check signature authorize automatic withdrawal time never set fear automatica withdraw suddently going effect refused send payment someone would agree something never would want keep house found cfr part rin application regulation z ability repay rule certain situation involving successor interest believe mortgage company violated rule made clear mortgage company every intention keeping home paying mortgage filed foreclosure rule really hit home read talking several different people citifiancial ask ask modification others tell modification possible appears along lastly wife power attorney permission speak anyone regarding anything pertaining matter attaching foreclosure petition answer death cert probate power attorney correspondence mortgage company
# 1112418  cfbp would like file complaint experian reporting agency sent via cerified mail letter asking experian investigate credit inquires see letter asked detail infomation reguarding inquires got letter stating remove inquires number failed send information asked send order verify fraudulent inquires asked experian please send info please remove item asap able verify info requested inportant experian failing send updated credit report delted updating information violation fcra req updated credit report company
# 1112419  husband middle fha short sale property located ga fha requirement late mortgage get fha short sale approval supporting document uploaded please examine audit credit see credit report creditor show excellent paid time never
#
# [1112420 rows x 3 columns]

# %%
#Eliminate 'Unnamed:0' column.
ndf.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
#Check how many null values are in the Complaint column.
print('Product Nulls: ', ndf['Product'].isnull().sum())
print('Complaint Nulls: ', ndf['Complaint'].isnull().sum())
# Out:
# Product Nulls:  0
# Complaint Nulls:  81

# %%
#Visualize null and non-null values in product and complaint features.
msno.matrix(ndf)
# Out:
# <AxesSubplot:>

# %%
#Sample narrative after preprocessing.
ndf.Complaint[0]
# Out:
# 'owe money never received bill indicating balance due never received demand letter indicating amount due paid date collection action begin payment service date money service due returned equipment received previously contracted provided receipt information would appear engaged provided information ic system ic system placed derogatory item credit report'

# %%
#Eliminate all null values.
ndf = ndf.dropna()

# %%
ndf.head()
# Out:
#                          Product  \
# 0  Debt Collection
# 1  Debt Collection
# 2  Credit Reporting and Services
# 3  Banking Services
# 4  Credit Reporting and Services
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Complaint
# 0  owe money never received bill indicating balance due never received demand letter indicating amount due paid date collection action begin payment service date money service due returned equipment received previously contracted provided receipt information would appear engaged provided information ic system ic system placed derogatory item credit report
# 1  attempting collect fund valuation service provided see responded false allegation requested supporting documentation appraisal provided attempted withdraw business owes account unsuccessful added returned item fee balance owed new total owed due immediately youve already sent payment ignore notice business pay call u pay phone credit card check question also chat u click upload completed payment coupon using secure portal business ca pay full amount call chat u talk option also get help managing business payment account merchant service center thanks account business name case number
# 2  experian didnt consent inquiry also name incorrect address wrong correct information ga title b false activity without written consent title usc without written consent considered identity theft tile usc didnt notify activity still
# 3  citibank froze account contained time make college tuition payment daughter reason result forced make payment incur processing fee college paid credit card instead transfer checking account
# 4  accordance fair credit reporting act account violated section state right privacy section section state consumer reporting company furnish account without written instruction never given

# %%
ndf.shape
# Out:
# (1112339, 2)

# %%
# Plotting the countplot for 'product' column
sb.countplot(data=ndf, y='Product')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Product'>

# %% [markdown]
# # Encoding products.

# %%
#View list of products in Product feature.
ndf['Product'].unique()
# Out:
# array(['Debt Collection', 'Credit Reporting and Services',
#        'Banking Services', 'Mortgages', 'Credit/Prepaid Cards', 'Loans',
#        'Crypto Currency'], dtype=object)

# %%
#Encode products in numeric values.
ndf['Product'].replace({'Debt Collection' : 0, 
                        'Credit Reporting and Services' : 1,
                        'Banking Services' : 2,
                        'Mortgages' : 3,
                        'Credit/Prepaid Cards' : 4,
                        'Loans' : 5,
                        'Crypto Currency' : 6}, inplace=True)
# Out:
# /var/folders/3n/y6l_g9s960lc_759jvhdhxp40000gn/T/ipykernel_7230/2326779837.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndf['Product'].replace({'Debt Collection' : 0,

# %% [markdown]
# # Generate training and test set.

# %%
#Create train and test sets.
x = ndf['Complaint']
y = ndf['Product']

# %%
#Train and test sets are split 80/20.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print("Training set size:" , x_train.shape)
print("Test set size:" , x_test.shape)
# Out:
# Training set size: (889871,)
# Test set size: (222468,)

# %% [markdown]
# # Using TF-IDF Vectorizer to obtain relevance of each word in complaint narratives.

# %%
tfidf = TfidfVectorizer(max_features=900000, ngram_range=(1,2))
tfidf_x_train = tfidf.fit_transform(x_train)
tfidf_x_test = tfidf.transform(x_test)

# %% [markdown]
# # Model construction using Multinominal Naive Bayes classifier.

# %%
nb = MultinomialNB()
nb.fit(tfidf_x_train, y_train)
# Out:
# MultinomialNB()

# %%
#Predictions for training and testing set.
pred_y_train = nb.predict(tfidf_x_train)
pred_y_test = nb.predict(tfidf_x_test)

# %%
train_score = accuracy_score(y_train, pred_y_train)
test_score = accuracy_score(y_test, pred_y_test)

print('Prediction Accuracy (Train): ', 100*(round(train_score, 2)), '%')
print('Prediction Accuracy (Test): ', 100*(round(test_score, 2)), '%')
# Out:
# Prediction Accuracy (Train):  87.0 %
# Prediction Accuracy (Test):  85.0 %

# %% [markdown]
# # Classification details.

# %%
def getMetrics(org_data, pred_data):
    precision = precision_score(org_data, pred_data, average='weighted')
    recall = recall_score(org_data, pred_data, average='weighted')
    f1 = f1_score(org_data, pred_data, average='weighted')
    accuracy = accuracy_score(org_data, pred_data)
    
    print("Metrics:\n")
    print("   Precision: ", round(precision, 4),
         "\n   Recall: ", round(recall, 4),
         "\n   F1-Score: ", round(f1, 4),
         "\n   Accuracy: ", round(accuracy, 4))

# %%
#Generates confusion matrix.
def genCMatrix(org_data, pred_data):
    cmat = confusion_matrix(org_data, pred_data)

    disp_fig = metrics.ConfusionMatrixDisplay(confusion_matrix = cmat)
    disp_fig.plot()
    
    print('\n\nConfusion Matrix:')
    plt.show()

# %%
train_clsf_report = classification_report(y_train, pred_y_train)
test_clsf_report = classification_report(y_test, pred_y_test)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Training set evaluation.

# %%
getMetrics(y_train, pred_y_train)
print('\n\n\nClassification Report:\n\n', train_clsf_report)
genCMatrix(y_train, pred_y_train)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics:
#
#    Precision:  0.8645
#    Recall:  0.8659
#    F1-Score:  0.8637
#    Accuracy:  0.8659
#
#
#
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.82      0.77      0.80    153766
#            1       0.89      0.93      0.91    436927
#            2       0.87      0.90      0.88     77725
#            3       0.88      0.94      0.91     78211
#            4       0.81      0.77      0.79     81504
#            5       0.86      0.65      0.74     61725
#            6       0.00      0.00      0.00        13
#
#     accuracy                           0.87    889871
#    macro avg       0.73      0.71      0.72    889871
# weighted avg       0.86      0.87      0.86    889871
#
#
#
# Confusion Matrix:

# %% [markdown]
# ### Test set evaluation.

# %%
getMetrics(y_test, pred_y_test)
print('\n\nClassification Report:\n\n', test_clsf_report)
genCMatrix(y_test, pred_y_test)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics:
#
#    Precision:  0.8494
#    Recall:  0.8514
#    F1-Score:  0.8486
#    Accuracy:  0.8514
#
#
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.80      0.75      0.78     38161
#            1       0.88      0.93      0.90    108891
#            2       0.85      0.87      0.86     19693
#            3       0.87      0.93      0.90     19533
#            4       0.78      0.74      0.76     20568
#            5       0.84      0.61      0.71     15619
#            6       0.00      0.00      0.00         3
#
#     accuracy                           0.85    222468
#    macro avg       0.72      0.69      0.70    222468
# weighted avg       0.85      0.85      0.85    222468
#
#
#
# Confusion Matrix:
